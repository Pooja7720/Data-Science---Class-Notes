# %% [markdown]
# # Data types in python :
# - In python, all data has an associated data "Type".
# - You can find the "Type" of any piece of data by using the type() function.
# type("Hi!") produces <type 'str'>
# type( True ) produces <type 'bool'>
# type( 5) produces <type 'int'>
# type(5.0) produces <type 'float'>
# - Note that python supports two different types of numbers, Integers (int) and Floating point numbers (Float). Floating point numbers have a fractional part (digits after the decimal place), while integers do not!
# - As we know that, print() function is used to print the data likewise, type() is a function (Internally in python some words are defined, they are called as keywords) which returns the data type of variable passed to it.
# - type and print are keywords, but type and print with () are called functions.
# - type, print  -> Keywords
# - type(), functions()  ->  Functions
# - It doesn't matter the number is positive or negative, type() function do not affect the sign of number.

# %% [markdown]
# ## Python Data Types
#
# ### Built In Data Types:
# - Data types represent the type of data present inside a variable.
# - In Python we are not required to specify the type explicitly. Based on value provided, the type till be assigned automatially.
# - Hence Python is Dynamically Typed Language.
# - According to need or requirement of project, we define data type.
# - Python has the following data types built-in by default, in these categories:
# 1. Text Type: **str**
# 2. Numeric Types: **int, float, complex**
# 3. Sequence Types: **list, tuple, range**
# 4. Mapping Type: **dict**
# 5. Set Types: **set, forzenset**
# 6. Boolean Type: **bool**
# 7. Binary Types: **bytes, bytearray, memoryview**

# %% [markdown]
# ![Screenshot%20%281012%29.png](attachment:Screenshot%20%281012%29.png)

# %% [markdown]
# ![Screenshot%20%281014%29.png](attachment:Screenshot%20%281014%29.png)

# %% [markdown]
# ## A) Numeric Data Type:
#
# ### 1. Integers:
# - Integers are just whole numbers, positive or negative.
# - Example: 20 an -12
#
# **We can represent int values in python in the following ways**
# 1. Decimal form
# 2. Binary form
# 3. Octal form
# 4. Hexa decimal form
#
# #### 1. Decimal form
# - It is the default number system in Python
# - The allowed digits are: **0 to 9**

# %%
# Eg:
a = 10
type(a)
# Out:
# int

# %% [markdown]
# #### 2. Binary form(Base-2):
# - The allowed digits are: **0 & 1**
# - Literal value should be prefixed with **0b or 0B**

# %%
# Eg:
a = 0B1011
a = 0b111
print(type(a))
a
# Out:
# <class 'int'>
# 7

# %%
a = 0B123 # INVALID
# Because binary is only in the form of 0 and 1
# Out:
#   File "<ipython-input-3-d4cadba3a2c5>", line 1
#     a = 0B123 # INVALID
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### 3. Octal Form(Base-8):
# - The allowed digits are : **0 to 7**
# - Literal value should be prefixed with **0o or 0O**

# %%
# Eg:
a = 0o123
print(type(a))
a
# Out:
# <class 'int'>
# 83

# %% [markdown]
# #### 4. Hexa Decimal Form(Base-16):
# - The allowed digits are: **0 to 9, a-f** (Both lower and upper cases are allowed)
# - Literal value should be prefixed with **0x or 0X**

# %%
# Eg:
a = 0X10
a = 0XFACE
print(type(a))
a
# Out:
# <class 'int'>
# 64206

# %%
b = 0Xbeer
# r is not within a-f hence it will throw error
# r is outside the range of hexa decimal
# Out:
#   File "<ipython-input-6-226d3b886ca8>", line 1
#     b = 0Xbeer
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 2. Float:
# - Floating point numbers have a decimal point in them, or use an exponential(e) to define the number.
# - Main advantage of exponential form is we can represent big values in less memory

# %%
f = 1089.234
f
# Out:
# 1089.234

# %%
type(f)
# Out:
# float

# %%
f = 1.2e3
# 1.2 * e^3
#1.2 * 10^3 = 1200
f
# Out:
# 1200.0

# %%
4E3
# 4 * 10^3 = 4000
# Out:
# 4000.0

# %% [markdown]
# ### 3. Complex Numbers:
# - Complex numbers are written with a **"j"** as the imaginary part.
# - Real part can be of integers, floating point, octal, binary or hexa decimal form.
# - But imaginary part should be specified by using decimal form (We can't use octal, binary, hexa decimal in imaginary part).

# %%
b = 10 + 3.6j

# %%
a = 0B11 + 5j
a
# Out:
# (3+5j)

# %%
a = 10 + 1.5j
b = 20 + 2.5j
c = a + b
c
# Out:
# (30+4j)

# %%
type(c)
# Out:
# complex

# %%
# Retrive real part of a complex number
c.real
# Out:
# 30.0

# %%
# Retrive Imaginary part of a complex number
c.imag
# Out:
# 4.0

# %% [markdown]
# ## B) Text Type:
#
# ### 1. str:
# - It contains string data type as a text type
# - We have to represent this type of data either in single or double quotes

# %%
a = "Hello Everyone!"
print(a)
print(type(a))
# Out:
# Hello Everyone!
# <class 'str'>

# %% [markdown]
# ## C) Sequence Types:
#
# ### 1. List:
# - It is like an array.
# - It is represented as square brackets [ ]
# - List items are ordered, changable, indexed and allow duplicate members.

# %%
fruits = ["Apple","Banana","Cherry","Orange"]
print(fruits)
print(type(fruits))
# Out:
# ['Apple', 'Banana', 'Cherry', 'Orange']
# <class 'list'>

# %% [markdown]
# ### 2. Tuple:
# - It is represented as round brackets ( )
# - Tuple items are ordered, unchangable, indexed and allow duplicate members.

# %%
colors = ("Red","Violet","Green","Orange")
print(colors)
print(type(colors))
# Out:
# ('Red', 'Violet', 'Green', 'Orange')
# <class 'tuple'>

# %% [markdown]
# ### 3. Range:
# - Range function is used to get items in specific range.
# - The starting value is included and the end value is excluded.
# - Syntax : `range(1,6)`

# %%
x = range(2,9)
# It will loop from 2 to 8
print(x)
print(type(x))
# Out:
# range(2, 9)
# <class 'range'>

# %% [markdown]
# ## D) Mapping Type:
#
# ### 1. Dictionary:
# - It is a collection which is ordered, changable, indexed but no duplicate members.
# - It contains key value pair format.
# - It is represented using curly brackets { }
# - colon : is used to differentiate between key and value.

# %%
info = {"Name":"Priya","Surname":"Kapoor","Age":22}
print(info)
print(type(info))
# Out:
# {'Name': 'Priya', 'Surname': 'Kapoor', 'Age': 22}
# <class 'dict'>

# %% [markdown]
# ## E) Set Types:
#
# ### 1. Set:
# - It is a collection which is unordered, unchangable, unindexed, do not allow duplicates, heterogeneous(Allows items of different data types)
# - It is represented using curly brackets { }

# %%
Months = {"Jan","Feb","March","April","May","June","July"}
print(Months)
print(type(Months))
# Print in unordered fasion
# Out:
# {'May', 'Feb', 'June', 'Jan', 'April', 'March', 'July'}
# <class 'set'>

# %% [markdown]
# ### 2. Frozenset
# - Frozen set is just an immutable version of a Python set object.
# - While elements of a set can be modified at any time, elements of the frozen set remain the same after creation.
# - We can not add or update elements in frozen set.

# %%
# tuple of vowels
vowels = ('a', 'e', 'i', 'o', 'u')

fSet = frozenset(vowels)
print('The frozen set is:', fSet)
print('The empty frozen set is:', frozenset())

# frozensets are immutable
fSet.add('v')
# Out:
# The frozen set is: frozenset({'u', 'o', 'e', 'a', 'i'})
# The empty frozen set is: frozenset()
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-46ef7116a3e5> in <module>
#       7
#       8 # frozensets are immutable
# ----> 9 fSet.add('v')
#
# AttributeError: 'frozenset' object has no attribute 'add'

# %% [markdown]
# ## F) Boolean Type:
#
# ### 1. Bool:
# - It’s used to represent the truth value of an expression.
# - It have only two outputs, that are either True or False.
# - Mostly it is used in conditional statements.

# %%
1 <= 2
# Out:
# True

# %%
"First" == "Second"
# Out:
# False

# %% [markdown]
# ### Basic Arihematic Operation in Python

# %%
# Addition
246 + 1146
# Out:
# 1392

# %%
# Subtraction
245 - 1125
# Out:
# -880

# %%
# Multiplication
120 * 2
# Out:
# 240

# %%
# Powers
4**2
# Out:
# 16

# %%
# Roots
4**0.5
# Out:
# 2.0

# %%
# Cube root
4**(1/3)
# Out:
# 1.5874010519681994

# %%
# Division
7/4
# Out:
# 1.75

# %%
# Floor division - Rounding off to floor
7//4
# Out:
# 1

# %%
# Modulo - Reminder after division
7%4
# Out:
# 3

# %%
# Order of Operations
3 + 10 * 10 - 3
"""
Precedence:
* 
+ -
"""
# Out:
# 100

# %%
# Use parentheses to specify orders
(2 + 10) * (10 + 3)
# Out:
# 156

# %% [markdown]
# ![Screenshot%20%281016%29.png](attachment:Screenshot%20%281016%29.png)

# %%
# Value will be overwritten
a = 10
a = 20
print(a)
# Out:
# 20

# %%
# Same object assigned to different variables
a = 10
b = 10
print(a)
print(b)
# Out:
# 10
# 10

# %% [markdown]
# #### To get address of object in Memory Location - id() Function

# %%
a = 10
b = 10
print(id(a))
print(id(b))
# Here it is giving same id means
# Both the variables point to the same object.
# Out:
# 140715036226768
# 140715036226768

# %% [markdown]
# If we assign different values to the variable, then it's id changes

# %%
a = 10
print(id(a))
# Out:
# 140715036226768

# %%
a = 20
print(id(a))
# Out:
# 140715036227088

# %% [markdown]
# ### Variables Reassignment
# - We can **add, subtract, multiply and divide** numbers with reassignment using **+=, -=, *=, /=**

# %%
x = 5
x = x + 10 # is equal to x+=10
print(x)
# Out:
# 15

# %%
a = 2
type(a) 
# As a is a variable, and we can find the type of variable
# Out:
# int

# %%
a = -7980
b = "Hi all, I am learning data science"
#c = true 
''' -> Here it will give an error because true is not a keyword or 
not considered as string here.'''
d = True
e = -45.87
print(type(a))
print(type(b))
#type(c)
print(type(d))
print(type(e))
'''Here instead of print if you use only type(a) for a to e then it will 
print only type of e, so we have to use print() function'''
# To print data types of all variables.
# Out:
# <class 'int'>
# <class 'str'>
# <class 'bool'>
# <class 'float'>

# %% [markdown]
# - If you are using print function for printing the type of variable then it will treat it as a class attribute
#   Ex : print(type(a))
# - If you are directly typing the type of variable then it will directly give you the type of variable, but you have to use type() for every cell cause in a single cell it will not give type() of two variables
#   Ex : type(a) -> only one variable is allowed to get its type, if you want to get type of other variable also then use another cell to printing it's type.

# %% [markdown]
# ### Complex Data type :
# - Complex data type also present in python which is in the form of x + yj
# - You have to use numbers at the place of x and y, you can not use variables. This is a drawback of complex numbers in case of python.
# - Only j is used as a imaginary number, i is not used like our mathematical calculation

# %%
a = 3 + 4i
# Out:
#   File "<ipython-input-7-d24e04444fb5>", line 1
#     a = 3+4i
#            ^
# SyntaxError: invalid syntax

# %%
a = 3 + 4j
type(a)
# Out:
# complex

# %%
x = 10
y = 20
b = x + yj # You can only use numbers here, variables are not used 
type(b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-a0da6ba3ebfe> in <module>
#       1 x = 10
#       2 y = 20
# ----> 3 b = x + y*j
#       4 type(b)
#
# NameError: name 'j' is not defined

# %% [markdown]
# ### Determining variable type with - type() Function

# %%
x = 10
type(x)
# Out:
# int

# %%
x = [1,2,3]
type(x)
# Out:
# list

# %%
x = "Data Science"
type(x)
# Out:
# str

# %% [markdown]
# ### Type Casting / Type Conversion :
# The process of conversion of one data type to another is called as type casting.
# - Type casting is also called as type conversion
# - Data can sometimes be converted from one type to another. For example, the string "3.0" is equivalent to the floating point number 3.0, which is equivalent to the integer number 3.
# - Functions exists which will take data in one type and return data in another type.
#   - int() - Converts compatible data into an integer. This function will truncate floating point numbers
#   - float() - Converts compatible data into a float.
#   - str() - Converts compatible data into a string.
# - Examples:
#   - int(3.3) produces 3
#   - str(3.3) produces "3.3"
#   - float(3) produces 3.0
#   - float("3.5") produces 3.5
#   - int("7") produces 7
#   - int("7.1") produces ERROR (Because it's not a base 10 value to convert it to the integer)
#   - float("Test") produces ERROR (Because this string is not a value and it's not possible to convert letters to numbers)
#   - **That's why python is called dynamically typed language because on the run it will assign data type according to data**

# %%
x = '345' # x is a string

# %%
type(x)
# Out:
# str

# %%
int(x) # Converting a string to integer.
# Out:
# 345

# %% [markdown]
# Some type casting methods are not possible
# Ex : Conversion of a string to integer, which is really not a fruitful method

# %%
a = "Hi!"
type(a)
# Out:
# str

# %%
int(a) 
"""In this case, Conversion of string to integer is not possible, 
so it will give an error"""
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-8b2ab3991dae> in <module>
# ----> 1 int(a)
#
# ValueError: invalid literal for int() with base 10: 'Hi!'

# %%
w = 56.78
type(w)
# Out:
# float

# %%
str(w)
# Out:
# '56.78'

# %% [markdown]
# If you are passing float in a string and you are expecting integer value from it then it will throw an error. Because for converting that string value to integer, it must be of base 10. So solution fo it is firstly convert it to float and then to integer.

# %%
a = '78.90'
type(a)
# Out:
# str

# %%
float(a) # It will convert it to float variable
# Out:
# 78.9

# %%
int(a) 
"""It will not convert it to integer, 
because it requires base 10 to convert to integer."""
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-8b2ab3991dae> in <module>
# ----> 1 int(a)
#
# ValueError: invalid literal for int() with base 10: '78.90'

# %%
a = 78.90
b = float(a)
int(b) 
"""Instead of above, 
if you want to convert string to integer then use this method."""
# Out:
# 78

# %%
w = -12.98
str(w)
# Out:
# '-12.98'

# %%
int(w)
# Out:
# -12

# %%
f = "Hi 54 kkk"
int(f)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-c282eedfbb4e> in <module>
#       1 f = "Hi 54 kkk"
# ----> 2 int(f)
#
# ValueError: invalid literal for int() with base 10: 'Hi 54 kkk'

# %% [markdown]
# ### Effect of Data Types on Operator Results
# - Math operators work differently on Floats and Ints
#   - int + int produces an int
#   - int + float or float + int produces an float
# - This is especially important for division, as integer division produces a different result from floating point division.
#   - 10 // 3 produces 3
#   - 10 / 3 produces 3.3333
#   - 10.0 / 3.0 produces 3.3333333
# - Other Operators work differently on different data types : + (addition) will add two numbers, but concatinate strings.
#
# ### Simple Data Types in Python
# The simple data types in python are:
# - Numbers
#   - int -- Integer: -5, 10, 77
#   - float -- Floating Point numbers: 3.1457, 0.34
# - Bool - Booleans (True or False)
# - Strings are a more complicated data types (called Sequences). They are made up of individual letters (string of length 1)

# %% [markdown]
# ![Screenshot%20%28878%29.png](attachment:Screenshot%20%28878%29.png)

# %% [markdown]
# #### Program Example
# Find the area of a circle given the radius:

# %%
Radius = 10
pi = 3.14159
area = pi * Radius * Radius
print("Area of circle is : " + str(area))
# Out:
# Area of circle is : 314.159

# %% [markdown]
# **Give meaningfull name to the variable to increase code readability.**
